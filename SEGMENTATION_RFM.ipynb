# %% [markdown]
#   ## SEGMENTATION PAR LA METHODE RFM

# %%
import matplotlib.image as mpimg
image = mpimg.imread("segment.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# # AU SUJET DE LA SEGMENTATION RFM

# %% [raw]
# La segmentation de la clientèle est importante pour plusieurs raisons. Nous acquérons une connaissance plus approfondie de nos clients et pouvons adapter des campagnes marketing ciblées.
#
# La méthode RFM a été introduite par Bult et Wansbeek en 1995 et a été utilisée avec succès par les spécialistes du marketing depuis.
# Il analyse le comportement des clients sur trois paramètres :
# Récence : date à laquelle le dernier achat du client est récent.
# Fréquence : la fréquence à laquelle le client effectue un achat.
# Monétaire : combien d'argent le client dépense-t-il.
#
# L'avantage de RFM est qu'il est facile à mettre en œuvre et qu'il peut être utilisé pour différents types d'entreprises. Il aide à concevoir de meilleures campagnes marketing et améliore le CRM et la fidélité des clients.
#
# Les inconvénients sont qu'il peut ne pas s'appliquer dans les industries où les clients sont généralement des acheteurs ponctuels. Il est basé sur des données historiques et ne donnera pas beaucoup d'informations sur les prospects.

# %% [markdown]
# # METHODOLOGIE

# %% [raw]
# Pour obtenir le score RFM d'un client, nous devons d'abord calculer les scores R, F et M sur une échelle de 1 (pire) à 5 (meilleur).
#
# calculer Récence = nombre de jours depuis le dernier achat
# calculer Fréquence = nombre d'achats pendant la période étudiée (généralement un an)
# calculer Monétaire = montant total des achats effectués au cours de la période étudiée
# trouver des quintiles pour chacune de ces dimensions
# attribuer une note à chaque dimension en fonction du quintile dans lequel elle se situe
# combiner les scores R, F et M pour obtenir le score RFM
# mapper les scores RF aux segments

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

from datetime import timedelta

# %%
sales = pd.read_excel('online retail.xlsx')
sales.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
print('{:,} rows; {:,} columns'.format(sales.shape[0], sales.shape[1]))
# Out:
# 541,909 rows; 8 columns

# %%
sales.dropna(subset=['CustomerID'], inplace=True)

# %%
print('Orders from {} to {}'.format(sales['InvoiceDate'].min(),
                                    sales['InvoiceDate'].max()))
# Out:
# Orders from 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %%
sales
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Price
# ...

# %%
sales1=sales[['InvoiceNo','InvoiceDate','CustomerID','Country']]
sales1.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of        InvoiceNo         InvoiceDate  CustomerID         Country
# 0         536365 2010-12-01 08:26:00     17850.0  United Kingdom
# 1         536365 2010-12-01 08:26:00     17850.0  United Kingdom
# 2         536365 2010-12-01 08:26:00     17850.0  United Kingdom
# 3         536365 2010-12-01 08:26:00     17850.0  United Kingdom
# 4         536365 2010-12-01 08:26:00     17850.0  United Kingdom
# ...          ...                 ...         ...             ...
# 541904    581587 2011-12-09 12:50:00     12680.0          France
# 541905    581587 2011-12-09 12:50:00     12680.0          France
# 541906    581587 2011-12-09 12:50:00     12680.0          France
# 541907    581587 2011-12-09 12:50:00     12680.0          France
# 541908    581587 2011-12-09 12:50:00     12680.0          France
#
# [406829 rows x 4 columns]>

# %%
tab=sales.groupby(['InvoiceNo', 'InvoiceDate','CustomerID']).size()

# %%
tab
# Out:
# InvoiceNo  InvoiceDate          CustomerID
# 536365     2010-12-01 08:26:00  17850.0        7
# 536366     2010-12-01 08:28:00  17850.0        2
# 536367     2010-12-01 08:34:00  13047.0       12
# 536368     2010-12-01 08:34:00  13047.0        4
# 536369     2010-12-01 08:35:00  13047.0        1
#                                               ..
# C581484    2011-12-09 09:27:00  16446.0        1
# C581490    2011-12-09 09:57:00  14397.0        2
# C581499    2011-12-09 10:28:00  15498.0        1
# C581568    2011-12-09 11:57:00  15311.0        1
# C581569    2011-12-09 11:58:00  17315.0        2
# Length: 22221, dtype: int64

# %%
tab2=tab.groupby(['CustomerID']).size()
tab2
# Out:
# CustomerID
# 12346.0     2
# 12347.0     7
# 12348.0     4
# 12349.0     1
# 12350.0     1
#            ..
# 18280.0     1
# 18281.0     1
# 18282.0     3
# 18283.0    16
# 18287.0     3
# Length: 4372, dtype: int64

# %%
sales['Price'] = sales['Quantity'] * sales['UnitPrice']

# %%
sales['InvoiceNo'].value_counts().head()
# Out:
# 576339    542
# 579196    533
# 580727    529
# 578270    442
# 573576    435
# Name: InvoiceNo, dtype: int64

# %%
orders = sales.groupby(['InvoiceNo', 'InvoiceDate', 'CustomerID']).agg({'Price': lambda x: x.sum()}).reset_index()
orders.head(10)
# Out:
#   InvoiceNo         InvoiceDate  CustomerID   Price
# 0    536365 2010-12-01 08:26:00     17850.0  139.12
# 1    536366 2010-12-01 08:28:00     17850.0   22.20
# 2    536367 2010-12-01 08:34:00     13047.0  278.73
# 3    536368 2010-12-01 08:34:00     13047.0   70.05
# 4    536369 2010-12-01 08:35:00     13047.0   17.85
# 5    536370 2010-12-01 08:45:00     12583.0  855.86
# 6    536371 2010-12-01 09:00:00     13748.0  204.00
# 7    536372 2010-12-01 09:01:00     17850.0   22.20
# 8    536373 2010-12-01 09:02:00     17850.0  259.86
# 9    536374 2010-12-01 09:09:00     15100.0  350.40

# %%
NOW = orders['InvoiceDate'].max() + timedelta(days=1)
NOW
# Out:
# Timestamp('2011-12-10 12:50:00')

# %%
period = 365

# %%
orders['DaysSinceOrder'] = orders['InvoiceDate'].apply(lambda x: (NOW - x).days)

# %%
aggr = {
    'DaysSinceOrder': lambda x: x.min(),  # the number of days since last order (Recency)
    'InvoiceDate': lambda x: len([d for d in x if d >= NOW - timedelta(days=period)]), # the total number of orders in the last period (Frequency)
}
rfm = orders.groupby('CustomerID').agg(aggr).reset_index()
rfm.rename(columns={'DaysSinceOrder': 'Recency', 'InvoiceDate': 'Frequency'}, inplace=True)
rfm.head()
# Out:
#    CustomerID  Recency  Frequency
# 0     12346.0      326          2
# 1     12347.0        2          6
# 2     12348.0       75          4
# 3     12349.0       19          1
# 4     12350.0      310          1

# %%
rfm['Monetary'] = rfm['CustomerID'].apply(lambda x: orders[(orders['CustomerID'] == x) & \
                                                           (orders['InvoiceDate'] >= NOW - timedelta(days=period))]\
                                                           ['Price'].sum())
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12346.0      326          2      0.00
# 1     12347.0        2          6   3598.21
# 2     12348.0       75          4   1797.24
# 3     12349.0       19          1   1757.55
# 4     12350.0      310          1    334.40

# %%
quintiles = rfm[['Recency', 'Frequency', 'Monetary']].quantile([.2, .4, .6, .8]).to_dict()
quintiles
# Out:
# {'Recency': {0.2: 11.0, 0.4: 32.0, 0.6: 71.0, 0.8: 178.80000000000018},
#  'Frequency': {0.2: 1.0, 0.4: 2.0, 0.6: 3.0, 0.8: 6.0},
#  'Monetary': {0.2: 215.89800000000002,
#   0.4: 440.432,
#   0.6: 876.3679999999999,
#   0.8: 1909.6580000000006}}

# %%
def r_score(x):
    if x <= quintiles['Recency'][.2]:
        return 5
    elif x <= quintiles['Recency'][.4]:
        return 4
    elif x <= quintiles['Recency'][.6]:
        return 3
    elif x <= quintiles['Recency'][.8]:
        return 2
    else:
        return 1

def fm_score(x, c):
    if x <= quintiles[c][.2]:
        return 1
    elif x <= quintiles[c][.4]:
        return 2
    elif x <= quintiles[c][.6]:
        return 3
    elif x <= quintiles[c][.8]:
        return 4
    else:
        return 5

# %%
rfm['R'] = rfm['Recency'].apply(lambda x: r_score(x))
rfm['F'] = rfm['Frequency'].apply(lambda x: fm_score(x, 'Frequency'))
rfm['M'] = rfm['Monetary'].apply(lambda x: fm_score(x, 'Monetary'))

# %%
rfm['RFM Score'] = rfm['R'].map(str) + rfm['F'].map(str) + rfm['M'].map(str)
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  R  F  M RFM Score
# 0     12346.0      326          2      0.00  1  2  1       121
# 1     12347.0        2          6   3598.21  5  4  5       545
# 2     12348.0       75          4   1797.24  2  4  4       244
# 3     12349.0       19          1   1757.55  4  1  4       414
# 4     12350.0      310          1    334.40  1  1  2       112

# %%
segt_map = {
    r'[1-2][1-2]': 'hibernating',
    r'[1-2][3-4]': 'at risk',
    r'[1-2]5': 'can\'t loose',
    r'3[1-2]': 'about to sleep',
    r'33': 'need attention',
    r'[3-4][4-5]': 'loyal customers',
    r'41': 'promising',
    r'51': 'new customers',
    r'[4-5][2-3]': 'potential loyalists',
    r'5[4-5]': 'champions'
}

rfm['Segment'] = rfm['R'].map(str) + rfm['F'].map(str)
rfm['Segment'] = rfm['Segment'].replace(segt_map, regex=True)
rfm.head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  R  F  M RFM Score      Segment
# 0     12346.0      326          2      0.00  1  2  1       121  hibernating
# 1     12347.0        2          6   3598.21  5  4  5       545    champions
# 2     12348.0       75          4   1797.24  2  4  4       244      at risk
# 3     12349.0       19          1   1757.55  4  1  4       414    promising
# 4     12350.0      310          1    334.40  1  1  2       112  hibernating

# %% [raw]
# Les scores RFM nous donnent 5*5*5 = 125 segments. Ce qui n'est pas facile à travailler.
# Nous allons travailler avec 11 segments basés sur les scores R et F. Voici la description des segments :

# %%
import matplotlib.image as mpimg
image = mpimg.imread("rfm-segments.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# # Visualisons nos segments de clients

# %% [raw]
# Maintenant que nous avons nos scores, nous pouvons faire une visualisation des données pour avoir une meilleure idée de notre portefeuille de clients. Voyons d'abord la distribution de R, F et M.

# %%
# plot the distribution of customers over R and F
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))

for i, p in enumerate(['R', 'F']):
    parameters = {'R':'Recency', 'F':'Frequency'}
    y = rfm[p].value_counts().sort_index()
    x = y.index
    ax = axes[i]
    bars = ax.bar(x, y, color='silver')
    ax.set_frame_on(False)
    ax.tick_params(left=False, labelleft=False, bottom=False)
    ax.set_title('Distribution of {}'.format(parameters[p]),
                fontsize=14)
    for bar in bars:
        value = bar.get_height()
        if value == y.max():
            bar.set_color('firebrick')
        ax.text(bar.get_x() + bar.get_width() / 2,
                value - 5,
                '{}\n({}%)'.format(int(value), int(value * 100 / y.sum())),
               ha='center',
               va='top',
               color='w')

plt.show()

# plot the distribution of M for RF score
fig, axes = plt.subplots(nrows=5, ncols=5,
                         sharex=False, sharey=True,
                         figsize=(10, 10))

r_range = range(1, 6)
f_range = range(1, 6)
for r in r_range:
    for f in f_range:
        y = rfm[(rfm['R'] == r) & (rfm['F'] == f)]['M'].value_counts().sort_index()
        x = y.index
        ax = axes[r - 1, f - 1]
        bars = ax.bar(x, y, color='silver')
        if r == 5:
            if f == 3:
                ax.set_xlabel('{}\nF'.format(f), va='top')
            else:
                ax.set_xlabel('{}\n'.format(f), va='top')
        if f == 1:
            if r == 3:
                ax.set_ylabel('R\n{}'.format(r))
            else:
                ax.set_ylabel(r)
        ax.set_frame_on(False)
        ax.tick_params(left=False, labelleft=False, bottom=False)
        ax.set_xticks(x)
        ax.set_xticklabels(x, fontsize=8)

        for bar in bars:
            value = bar.get_height()
            if value == y.max():
                bar.set_color('firebrick')
            ax.text(bar.get_x() + bar.get_width() / 2,
                    value,
                    int(value),
                    ha='center',
                    va='bottom',
                    color='k')
fig.suptitle('Distribution of M for each F and R',
             fontsize=14)
plt.tight_layout()
plt.show()

# %% [raw]
# On voit que si la récence semble bien répartie, près de la moitié des clients n'achètent pas très souvent (48 % des clients ont une fréquence de 1 ou 2).
# Lorsque l'on regarde la valeur monétaire, on constate que les clients dépensant le plus sont ceux qui ont l'activité la plus élevée (R et F de 4-5). Nous avons très peu de commandes importantes (valeur monétaire élevée mais fréquence faible).
#
# Regardons la distribution de nos segments.
# Je ne vais pas utiliser un treemap comme la matrice de segments ci-dessus pour visualiser la distribution des segments. Les graphiques à barres conviennent mieux pour comparer les quantités.

# %%
# count the number of customers in each segment
segments_counts = rfm['Segment'].value_counts().sort_values(ascending=True)

fig, ax = plt.subplots()

bars = ax.barh(range(len(segments_counts)),
              segments_counts,
              color='silver')
ax.set_frame_on(False)
ax.tick_params(left=False,
               bottom=False,
               labelbottom=False)
ax.set_yticks(range(len(segments_counts)))
ax.set_yticklabels(segments_counts.index)

for i, bar in enumerate(bars):
        value = bar.get_width()
        if segments_counts.index[i] in ['champions', 'loyal customers']:
            bar.set_color('firebrick')
        ax.text(value,
                bar.get_y() + bar.get_height()/2,
                '{:,} ({:}%)'.format(int(value),
                                   int(value*100/segments_counts.sum())),
                va='center',
                ha='left'
               )

plt.show()

# %% [raw]
# Nous avons beaucoup de clients qui n'achètent pas fréquemment chez nous (29% sont en hibernation). Cependant, 32% de nos clients sont soit des champions, soit des clients fidèles.
#
# Une analyse plus approfondie peut être effectuée en intégrant les paramètres monétaires.
# Avec des clients assignés à des segments et quelques statistiques sur la composition de notre portefeuille de clients, nous pouvons travailler sur des campagnes marketing ciblées pour fidéliser les clients à risque, améliorer les ventes aux clients avec un certain potentiel et récompenser les meilleurs clients.
