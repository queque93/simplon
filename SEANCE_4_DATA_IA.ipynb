# %% [markdown]
# # INITIATION A PANDAS

# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_table('heart.txt')

# %%
dataset
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin       100        234     A       A       156    non
# 1     41   feminin       130        204     A       C       172    non
# 2     58  masculin       150        270     A       C       111    oui
# 3     53  masculin       140        203     B       C       155    oui
# 4     41  masculin       130        214     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin       140        268     A       C       160    non
# 266   62  masculin       130        231     A       A       146    non
# 267   64  masculin       110        211     A       C       144    oui
# 268   63   feminin       150        407     A       C       154    non
# 269   35   feminin       138        183     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# ...

# %%
#verifier si il existe des données manquantes

dataset.isna()
# Out:
#        age   sexe  pression  cholester  sucre  electro  taux_max  angine  \
# 0    False  False     False      False  False    False     False   False
# 1    False  False     False      False  False    False     False   False
# 2    False  False     False      False  False    False     False   False
# 3    False  False     False      False  False    False     False   False
# 4    False  False     False      False  False    False     False   False
# ..     ...    ...       ...        ...    ...      ...       ...     ...
# 265  False  False     False      False  False    False     False   False
# 266  False  False     False      False  False    False     False   False
# 267  False  False     False      False  False    False     False   False
# 268  False  False     False      False  False    False     False   False
# 269  False  False     False      False  False    False     False   False
#
#      depression    pic  vaisseau  coeur
# 0         False  False     False  False
# ...

# %%
#Debombrer le nombre de données manquantes par variables

dataset.isna().sum()
# Out:
# age           0
# sexe          0
# pression      0
# cholester     0
# sucre         0
# electro       0
# taux_max      0
# angine        0
# depression    0
# pic           0
# vaisseau      0
# coeur         0
# dtype: int64

# %%
#Pourcentage de données manquantes par variables

(dataset.isna().sum()/len(dataset))*100
# Out:
# age           0.0
# sexe          0.0
# pression      0.0
# cholester     0.0
# sucre         0.0
# electro       0.0
# taux_max      0.0
# angine        0.0
# depression    0.0
# pic           0.0
# vaisseau      0.0
# coeur         0.0
# dtype: float64

# %%
df=pd.read_table('heart_1.txt')

# %%
df
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin     100.0      234.0     A       A       156    non
# 1     41   feminin       NaN      204.0     A       C       172    non
# 2     58  masculin     150.0      270.0     A       C       111    oui
# 3     53  masculin     140.0      203.0     B       C       155    oui
# 4     41  masculin     130.0      214.0     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin     140.0      268.0     A       C       160    non
# 266   62  masculin     130.0      231.0     A       A       146    non
# 267   64  masculin     110.0      211.0     A       C       144    oui
# 268   63   feminin     150.0      407.0     A       C       154    non
# 269   35   feminin     138.0      183.0     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# ...

# %%
df.isna().sum()
# Out:
# age           0
# sexe          0
# pression      2
# cholester     1
# sucre         0
# electro       0
# taux_max      0
# angine        3
# depression    0
# pic           0
# vaisseau      0
# coeur         0
# dtype: int64

# %%
(df.isna().sum()/len(df))*100
# Out:
# age           0.000000
# sexe          0.000000
# pression      0.740741
# cholester     0.370370
# sucre         0.000000
# electro       0.000000
# taux_max      0.000000
# angine        1.111111
# depression    0.000000
# pic           0.000000
# vaisseau      0.000000
# coeur         0.000000
# dtype: float64

# %%
#dimension du dataframe
df.shape
# Out:
# (270, 12)

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# age           0.000000
# sexe          0.000000
# pression      0.740741
# cholester     0.370370
# sucre         0.000000
# electro       0.000000
# taux_max      0.000000
# angine        1.111111
# depression    0.000000
# pic           0.000000
# vaisseau      0.000000
# coeur         0.000000
# dtype: float64

# %%
#utilisation de la fonction len 
a=(df.isna().sum()/len(df))*100

# %%
a
# Out:
# age           0.000000
# sexe          0.000000
# pression      0.740741
# cholester     0.370370
# sucre         0.000000
# electro       0.000000
# taux_max      0.000000
# angine        1.111111
# depression    0.000000
# pic           0.000000
# vaisseau      0.000000
# coeur         0.000000
# dtype: float64

# %%
#ranger dans l'ordre croissant
a.sort_values(ascending=True)
# Out:
# age           0.000000
# sexe          0.000000
# sucre         0.000000
# electro       0.000000
# taux_max      0.000000
# depression    0.000000
# pic           0.000000
# vaisseau      0.000000
# coeur         0.000000
# cholester     0.370370
# pression      0.740741
# angine        1.111111
# dtype: float64

# %%
#ranger dans l'ordre décroissant
a.sort_values(ascending=False)
# Out:
# angine        1.111111
# pression      0.740741
# cholester     0.370370
# coeur         0.000000
# vaisseau      0.000000
# pic           0.000000
# depression    0.000000
# taux_max      0.000000
# electro       0.000000
# sucre         0.000000
# sexe          0.000000
# age           0.000000
# dtype: float64

# %%
#Obtenir la colonne presentant la plus grande donnée manquante

df.isna().sum().nlargest(3)
# Out:
# angine       3
# pression     2
# cholester    1
# dtype: int64

# %%
#remplacer la valeur manquante de pression par la pression_moyenne

df['pression'].fillna(df['pression'].mean(),inplace=True) # inplace pour garder en memoire

# %%
df['pression'].isna().any()
# Out:
# False

# %%
#imputation sur plusieurs variables

df.fillna({'cholester':df['cholester'].mean(), 'pression':df['pression'].mean(),})
# Out:
#      age      sexe    pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin  100.000000      234.0     A       A       156    non
# 1     41   feminin  131.261194      204.0     A       C       172    non
# 2     58  masculin  150.000000      270.0     A       C       111    oui
# 3     53  masculin  140.000000      203.0     B       C       155    oui
# 4     41  masculin  130.000000      214.0     A       C       168    non
# ..   ...       ...         ...        ...   ...     ...       ...    ...
# 265   62   feminin  140.000000      268.0     A       C       160    non
# 266   62  masculin  130.000000      231.0     A       A       146    non
# 267   64  masculin  110.000000      211.0     A       C       144    oui
# 268   63   feminin  150.000000      407.0     A       C       154    non
# 269   35   feminin  138.000000      183.0     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# ...

# %%
#Tri a plat de la variable angine

df['angine'].value_counts()
# Out:
# non    179
# oui     88
# Name: angine, dtype: int64

# %%
#imputer par la moyenne et le mode 

df.fillna({'cholester':df['cholester'].mean(), 'pression':df['pression'].mean(), 'angine':'non'},inplace=True)

# %%
df.isna().sum()
# Out:
# age           0
# sexe          0
# pression      0
# cholester     0
# sucre         0
# electro       0
# taux_max      0
# angine        0
# depression    0
# pic           0
# vaisseau      0
# coeur         0
# dtype: int64

# %%
#supprimer la colonne angine

df.drop(["angine"], axis=1)         # del df['angine']
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max  depression  \
# 0     58  masculin     100.0      234.0     A       A       156           1
# 1     41   feminin       NaN      204.0     A       C       172          14
# 2     58  masculin     150.0      270.0     A       C       111           8
# 3     53  masculin     140.0      203.0     B       C       155          31
# 4     41  masculin     130.0      214.0     A       C       168          20
# ..   ...       ...       ...        ...   ...     ...       ...         ...
# 265   62   feminin     140.0      268.0     A       C       160          36
# 266   62  masculin     130.0      231.0     A       A       146          18
# 267   64  masculin     110.0      211.0     A       C       144          18
# 268   63   feminin     150.0      407.0     A       C       154          40
# 269   35   feminin     138.0      183.0     A       A       182          14
#
#      pic vaisseau     coeur
# ...

# %%
df
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max  depression  \
# 0     58  masculin     100.0      234.0     A       A       156           1
# 1     41   feminin       NaN      204.0     A       C       172          14
# 2     58  masculin     150.0      270.0     A       C       111           8
# 3     53  masculin     140.0      203.0     B       C       155          31
# 4     41  masculin     130.0      214.0     A       C       168          20
# ..   ...       ...       ...        ...   ...     ...       ...         ...
# 265   62   feminin     140.0      268.0     A       C       160          36
# 266   62  masculin     130.0      231.0     A       A       146          18
# 267   64  masculin     110.0      211.0     A       C       144          18
# 268   63   feminin     150.0      407.0     A       C       154          40
# 269   35   feminin     138.0      183.0     A       A       182          14
#
#      pic vaisseau     coeur
# ...

# %%
#supprimer les lignes qui contiennent les valeurs manquantes suivant la variable cholester

df.dropna(axis=0,subset=['cholester'],inplace=True)

# %%
df
# Out:
#      age      sexe  pression  cholester sucre electro  taux_max angine  \
# 0     58  masculin     100.0      234.0     A       A       156    non
# 1     41   feminin       NaN      204.0     A       C       172    non
# 2     58  masculin     150.0      270.0     A       C       111    oui
# 3     53  masculin     140.0      203.0     B       C       155    oui
# 4     41  masculin     130.0      214.0     A       C       168    non
# ..   ...       ...       ...        ...   ...     ...       ...    ...
# 265   62   feminin     140.0      268.0     A       C       160    non
# 266   62  masculin     130.0      231.0     A       A       146    non
# 267   64  masculin     110.0      211.0     A       C       144    oui
# 268   63   feminin     150.0      407.0     A       C       154    non
# 269   35   feminin     138.0      183.0     A       A       182    non
#
#      depression  pic vaisseau     coeur
# 0             1    1        B  presence
# ...

# %%
#Donner le nombre de femmes et d'hommes

df['sexe'].value_counts()
# Out:
# masculin    182
# feminin      87
# Name: sexe, dtype: int64

# %%
nbre_masc=(df['sexe']=='masculin').sum()
nbre_fem=(df['sexe']=='feminin').sum()

# %%
print("nbre_masc:",nbre_masc, "nbre_fem:",nbre_fem)
# Out:
# nbre_masc: 182 nbre_fem: 87

# %%
#Donner le tableau de contingence des personnes presentant une maladie cardiaque ou pas selon le sexe

tb=pd.crosstab(df['sexe'],df['coeur'])
tb
# Out:
# coeur     absence  presence
# sexe
# feminin        67        20
# masculin       83        99

# %%
#le type du tableau

type(tb)
# Out:
# pandas.core.frame.DataFrame

# %%
#calculer un taux d'erreur

(tb.iloc[0,1]+tb.iloc[1,0])/(tb.sum().sum())*100
# Out:
# 38.28996282527881

# %%
# Veille tecnologique sur les algorithmes de machine learning

- Régression linéaire

- Regression logistique

- Arbre de décision

- support vecteur machine

- Analyse discriminante

- randomforest

- Bagging

- Boosting
